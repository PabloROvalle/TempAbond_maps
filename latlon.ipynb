# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import pandas as pd
import time
import shutil
time0 = time.perf_counter()

# %%
# Fisrt we go to the directory where we have tha data
folderpath = 'C:/Users/povalle/Desktop/results/latlon_maps/'

path = 'C:/Users/povalle/Desktop/MIRI_eng/TempTest/All/'
#path = 'C:/Users/povalle/Desktop/MIRI_eng/TempTest/All-Thierry/'

# %%
#       The optimal way to reduce is to create three arrays. one for coord x, other for coord y, and other for the
#       data to represent.

os.chdir(path)
j = glob.glob('*.inv')
k = glob.glob('*.fuel')  # Change here to inv when we have the real data
l = glob.glob('*.res')
size = int(np.size(k))


# These functions will get the data from the name
def getx(row):
    return int(row[0:2])  # Change these to the correct format of the results in .inv
def gety(column):
    return int(column[3:5])  # Change these to the correct format of the results in .inv

col = np.linspace(0,1,size)
row = np.linspace(0,1,size)
pix = np.linspace(0,1,size)

for i in range(size):
    col[i] = getx(k[i])
    row[i] = gety(k[i])
    
col = col.astype(float).astype(int).astype(str)
row = row.astype(float).astype(int).astype(str)

# %%
# You have to create the repos you see in C:/Users/povalle/Desktop/results/latlon_maps/, as we are studying the south
# polar region: -61, -63, -65, -67, -69, -71, -73, -75, -77, -79

lat = np.zeros((size))
for i in range(size):
    f = open(k[i], "r")
    lat[i] = float(f.read(5)) 

for i in range(size):
    if lat[i] < -60 and lat[i] > -62:
        print(lat[i])
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-61/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-61/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-61/' + l[i])        
    elif lat[i] < -62 and lat[i] > -64:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-63/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-63/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-63/' + l[i])
    elif lat[i] < -64 and lat[i] > -66:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-65/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-65/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-65/' + l[i])
    elif lat[i] < -66 and lat[i] > -68:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-67/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-67/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-67/' + l[i])
    elif lat[i] < -68 and lat[i] > -70:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + l[i])
    elif lat[i] < -70 and lat[i] > -72:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-71/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-71/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-71/' + l[i])
    elif lat[i] < -72 and lat[i] > -74:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-73/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-73/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-73/' + l[i])
    elif lat[i] < -74 and lat[i] > -76:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-75/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-75/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-75/' + l[i])
    elif lat[i] < -76 and lat[i] > -78:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-77/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-77/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-77/' + l[i])
    elif lat[i] < -78 and lat[i] > -80:
        shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-79/' + j[i])
        shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-79/' + k[i])        
        shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-79/' + l[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14124/1513483403.py in <module>
#      26         shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-67/' + l[i])
#      27     elif lat[i] < -68 and lat[i] > -70:
# ---> 28         shutil.copyfile(path+j[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + j[i])
#      29         shutil.copyfile(path+k[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + k[i])
#      30         shutil.copyfile(path+l[i], 'C:/Users/povalle/Desktop/results/latlon_maps/-69/' + l[i])
#
# IndexError: list index out of range

# %%
os.chdir(folderpath + '-61/')

result = np.zeros((11,361))

j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[0,:] = array.mean(axis=1)

os.chdir(folderpath + '-63/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[1,:] = array.mean(axis=1)

os.chdir(folderpath + '-65/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[2,:] = array.mean(axis=1)

os.chdir(folderpath + '-67/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[3,:] = array.mean(axis=1)

os.chdir(folderpath + '-69/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[4,:] = array.mean(axis=1)

os.chdir(folderpath + '-71/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[5,:] = array.mean(axis=1)

os.chdir(folderpath + '-73/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[6,:] = array.mean(axis=1)

os.chdir(folderpath + '-75/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[7,:] = array.mean(axis=1)

os.chdir(folderpath + '-75/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[8,:] = array.mean(axis=1)

os.chdir(folderpath + '-77/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[9,:] = array.mean(axis=1)

os.chdir(folderpath + '-79/')
j = glob.glob('*.inv')
array = np.zeros((361,int(np.size(j))))
for i in range(int(np.size(j))):
    df = pd.read_csv(j[i], header=None, sep='\s+')
    array[:,i] = df[1]
    result[10,:] = array.mean(axis=1)
    
result = np.transpose(result)

# %%
up = 275
low = 100

a =result[low:up,2:]
result
# Out:
# array([[  0. , 339.1, 339.1, ..., 339.1, 339.1, 339.1],
#        [  0. , 333.4, 333.4, ..., 333.4, 333.4, 333.4],
#        [  0. , 327.7, 327.7, ..., 327.7, 327.7, 327.7],
#        ...,
#        [  0. , 751.2, 751.2, ..., 751.2, 751.2, 751.2],
#        [  0. , 757.1, 757.1, ..., 757.1, 757.1, 757.1],
#        [  0. , 763.1, 763.1, ..., 763.1, 763.1, 763.1]])

# %%
from matplotlib.colors import LogNorm

levels = [140,150,160,165,167.5,170,175,180,185]  #temperature levels

fig = plt.gcf()
fig.set_size_inches(10, 5)
plt.imshow(a, aspect='auto',vmin=130, vmax=190,extent=[-62,-80,low,up], cmap= 'hot', origin = 'lower')
contours = plt.contour(a, levels, colors='k', origin='lower', extent=[-62,-80,low,up])  # low and up levels latitude (62, 80)

plt.xlabel('latitude (°)', fontsize = 20)
plt.ylabel('level', fontsize = 20)
ax = plt.gca()
ax.tick_params(labelsize=15)
plt.clabel(contours, inline=1, fontsize=10)

cbar = plt.colorbar()
cbar.set_label(label='Temperature (K)',fontsize=20, labelpad=15)

cbar.ax.tick_params(labelsize=15)

plt.axhline(132, linestyle ='-.', color = 'black')

plt.axhline(172, linestyle ='-.', color = 'black')
plt.savefig('C:/Users/povalle/Desktop/tempmaplatlon.pdf')

# %%
fig = plt.gcf()
fig.set_size_inches(9, 5)
ax = plt.gca()
ax.tick_params(labelsize=15)
plt.plot([63,65,67,69,71,73,75,77,79],result[132,2:], color = 'blue')
plt.plot([63,65,67,69,71,73,75,77,79],result[172,2:], color = 'red')
plt.legend(['mean temperature at ~ 10 mbar','mean temperature at ~ 0.75 mbar'],loc='center right', fontsize = 15)
plt.xlabel('latitude (°)', fontsize = 20)
plt.ylabel('Temperature (K)', fontsize = 20)
plt.grid()
